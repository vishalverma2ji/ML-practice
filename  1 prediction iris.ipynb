# %%
import pandas as pd

# %%
from sklearn.ensemble import Rando  bvcxmForestClassifier

# %%
data = pd.read_csv("iris_setosa1.csv")

# %%
x = data.iloc[:,:-1]

# %%
x
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth
# 0           5.1         3.5          1.4         0.2
# 1           4.9         3.0          1.4         0.2
# 2           4.7         3.2          1.3         0.2
# 3           4.6         3.1          1.5         0.2
# 4           5.0         3.6          1.4         0.2
# 5           5.4         3.9          1.7         0.4
# 6           4.6         3.4          1.4         0.3
# 7           5.0         3.4          1.5         0.2
# 8           4.4         2.9          1.4         0.2
# 9           4.9         3.1          1.5         0.1
# 10          6.3         3.3          6.0         2.5
# 11          5.8         2.7          5.1         1.9
# 12          7.1         3.0          5.9         2.1
# 13          6.3         2.9          5.6         1.8
# 14          6.5         3.0          5.8         2.2
# 15          7.6         3.0          6.6         2.1
# 16          4.9         2.5          4.5         1.7
# 17          7.3         2.9          6.3         1.8
# 18          6.7         2.5          5.8         1.8
# 19          7.2         3.6          6.1         2.5

# %%
y = data.iloc[:,-1]

# %%
y
# Out:
# 0        Iris-setosa
# 1        Iris-setosa
# 2        Iris-setosa
# 3        Iris-setosa
# 4        Iris-setosa
# 5        Iris-setosa
# 6        Iris-setosa
# 7        Iris-setosa
# 8        Iris-setosa
# 9        Iris-setosa
# 10    Iris-virginica
# 11    Iris-virginica
# 12    Iris-virginica
# 13    Iris-virginica
# 14    Iris-virginica
# 15    Iris-virginica
# 16    Iris-virginica
# 17    Iris-virginica
# 18    Iris-virginica
# 19    Iris-virginica
# Name: Species, dtype: object

# %%
print(type(model))
# Out:
# <class 'abc.ABCMeta'>

# %%
model = RandomForestClassifier

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(x, y)
# Out:
# LogisticRegression()

# %%
prediction = model.predict([[5.1,3.5,1.4,0.2]])
# Out:
# C:\Users\visha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
prediction = model.predict([[6.5,3.0,5.8,2.2]])
# Out:
# C:\Users\visha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array(['Iris-virginica'], dtype=object)
